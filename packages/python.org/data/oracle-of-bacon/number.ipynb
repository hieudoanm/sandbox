# %% [markdown]
# # Number

# %%
import matplotlib.pyplot as plt

numbers = [
    {
        "number": 0,
        "people": 1,
    },
    {
        "number": 1,
        "people": 2054,
    },
    {
        "number": 2,
        "people": 206538,
    },
    {
        "number": 3,
        "people": 636793,
    },
    {
        "number": 4,
        "people": 238520,
    },
    {
        "number": 5,
        "people": 30365,
    },
    {
        "number": 6,
        "people": 4578,
    },
    {
        "number": 7,
        "people": 785,
    },
    {
        "number": 8,
        "people": 153,
    },
    {
        "number": 9,
        "people": 28,
    },
    {
        "number": 10,
        "people": 4,
    },
]

xLabel = list(map(lambda item: item.get("number"), numbers))
yLabel = list(map(lambda item: item.get("people"), numbers))

plt.bar(xLabel, yLabel, color="maroon", width=0.4)
plt.title("Bullet - Best Rating - Distribution")
plt.xlabel("Bullet - Best Rating")
plt.ylabel("Distribution")
plt.show()
