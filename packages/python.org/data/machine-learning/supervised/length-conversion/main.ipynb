# %% [markdown]
# [Medium](https://betterprogramming.pub/build-your-first-machine-learning-model-with-tensorflow-ffc2f7cbf4f2)

# %% [markdown]
# ## Importing the Necessary Libraries
#
# We start by importing the libraries we are going to use in our example.
#
# - We will import TensorFlow to create our Machine Learning model.
# - We will also import the Pandas library to read the CSV file with conversions from kilometers to miles.
# - And finally, we will import the Seaborn and Matlotlib libraries to paint the different results.

# %%
import tensorflow as tf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Sample Data
#
# We read a comma-separated values (Kilometres-miles.csv) file into our data frame. This file contains a series of correspondences between kilometers and miles values. We will use this data frame to train our model.
#
# A data frame is a two-dimensional, size-mutable, and heterogeneous tabular data.

# %%
test_data = []
k_m = 0.621371192
for kilometres in range(1, 101):
    miles = kilometres * k_m
    test_data.append({
        "kilometres": kilometres,
        "miles": miles
    })

# %%
df = pd.DataFrame(test_data)
df.info
# Out:
# <bound method DataFrame.info of     kilometres      miles
# 0            1   0.621371
# 1            2   1.242742
# 2            3   1.864114
# 3            4   2.485485
# 4            5   3.106856
# ..         ...        ...
# 95          96  59.651634
# 96          97  60.273006
# 97          98  60.894377
# 98          99  61.515748
# 99         100  62.137119
#
# [100 rows x 2 columns]>

# %% [markdown]
# ## Painting the Data Frame
#
# We plot the graph of the above values using the “scatterplot” method of the “seaborn” library that we have imported under the name “sns.” It shows us a graphical representation between the X (Kilometers) and Y (miles) correspondences.

# %%
print("Painting the correlations")
# Once we load seaborn into the session, everytime a matplotlib plot is executed, seaborn's default customizations are added
sns.scatterplot(df, x='kilometres', y='miles')
plt.show()
# Out:
# Painting the correlations

# %% [markdown]
# We define the input and the output of the data frame to train the model: X (Kilometers) is the input, and Y (Miles) is the output.

# %%
print("Define input(X) and output(Y) variables")
x_train = df['kilometres']
y_train = df['miles']
print(x_train, y_train)
# Out:
# Define input(X) and output(Y) variables
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: kilometres, Length: 100, dtype: int64 0      0.621371
# 1      1.242742
# 2      1.864114
# 3      2.485485
# 4      3.106856
#         ...
# 95    59.651634
# 96    60.273006
# 97    60.894377
# 98    61.515748
# 99    62.137119
# Name: miles, Length: 100, dtype: float64

# %% [markdown]
# ## Creating the Neural-Network
#
# Now, let’s use the “keras.Sequential” method to create a neural network to which “layers” are added sequentially. Each layer has the function of gradually distill the input data to obtain the desired output.

# %%
print("Creating the model")
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=[1]))
# Out:
# Creating the model

# %% [markdown]
# ## Compiling the Model
#
# Before our model is trained, we will add some additional settings during the compilation step.
#
# We will set up an optimizer and a loss function, which will measure our model's accuracy.
#
# - Adam optimization is a stochastic gradient descent method that is based on the adaptive estimation of first-order and second-order moments.
#   For this, we will use the mean square error-based loss function, which measures our predictions' mean square error.
#
# The objective of our model is to minimize this function.

# %%
print("Compiling the model")
model.compile(optimizer=tf.keras.optimizers.Adam(1), loss='mean_squared_error')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Compiling the model

# %% [markdown]
# ## Training the Model
#
# We are going to use the “fit” method to train our model. First, we pass the independent or input variable (X-Kilometers) and the target variable (Y-Miles).
#
# On the other hand, we indicate the number of epochs. In this case, 250 epochs. An epoch is an iteration over the entire X and Y data provided.
#
# - If the number of epochs is small, the error will be large and vice versa.
# - If the number of epochs is big, the execution of the algorithm will be slower.

# %%
print ("Training the model")
epochs_hist = model.fit(x_train, y_train, epochs = 250)
# Out:
# Training the model
# Epoch 1/250
# 4/4 [==============================] - 0s 2ms/step - loss: 6902.4106
# Epoch 2/250
# 4/4 [==============================] - 0s 3ms/step - loss: 5108.5566
# Epoch 3/250
# 4/4 [==============================] - 0s 2ms/step - loss: 537.1052
# Epoch 4/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3466.4272
# Epoch 5/250
# 4/4 [==============================] - 0s 1ms/step - loss: 737.8445
# Epoch 6/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1065.4418
# Epoch 7/250
# 4/4 [==============================] - 0s 1ms/step - loss: 767.2773
# Epoch 8/250
# 4/4 [==============================] - 0s 1ms/step - loss: 256.5680
# Epoch 9/250
# 4/4 [==============================] - 0s 819us/step - loss: 262.9092
# Epoch 10/250
# 4/4 [==============================] - 0s 889us/step - loss: 127.9762
# Epoch 11/250
# 4/4 [==============================] - 0s 970us/step - loss: 87.3565
# Epoch 12/250
# 4/4 [==============================] - 0s 880us/step - loss: 72.5818
# Epoch 13/250
# 4/4 [==============================] - 0s 912us/step - loss: 51.2215
# Epoch 14/250
# 4/4 [==============================] - 0s 1ms/step - loss: 31.1294
# Epoch 15/250
# 4/4 [==============================] - 0s 983us/step - loss: 23.4343
# Epoch 16/250
# 4/4 [==============================] - 0s 856us/step - loss: 18.4571
# Epoch 17/250
# 4/4 [==============================] - 0s 831us/step - loss: 5.0125
# Epoch 18/250
# 4/4 [==============================] - 0s 843us/step - loss: 12.3481
# Epoch 19/250
# 4/4 [==============================] - 0s 912us/step - loss: 1.8585
# Epoch 20/250
# 4/4 [==============================] - 0s 833us/step - loss: 6.5298
# Epoch 21/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.8392
# Epoch 22/250
# 4/4 [==============================] - 0s 857us/step - loss: 3.9628
# Epoch 23/250
# 4/4 [==============================] - 0s 793us/step - loss: 2.6937
# Epoch 24/250
# 4/4 [==============================] - 0s 749us/step - loss: 1.0559
# Epoch 25/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9645
# Epoch 26/250
# 4/4 [==============================] - 0s 993us/step - loss: 1.0383
# Epoch 27/250
# 4/4 [==============================] - 0s 834us/step - loss: 0.5932
# Epoch 28/250
# 4/4 [==============================] - 0s 797us/step - loss: 0.7801
# Epoch 29/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3724
# Epoch 30/250
# 4/4 [==============================] - 0s 853us/step - loss: 0.4406
# Epoch 31/250
# 4/4 [==============================] - 0s 740us/step - loss: 0.3431
# Epoch 32/250
# 4/4 [==============================] - 0s 821us/step - loss: 0.2315
# Epoch 33/250
# 4/4 [==============================] - 0s 951us/step - loss: 0.2264
# Epoch 34/250
# 4/4 [==============================] - 0s 774us/step - loss: 0.1841
# Epoch 35/250
# 4/4 [==============================] - 0s 757us/step - loss: 0.1501
# Epoch 36/250
# 4/4 [==============================] - 0s 828us/step - loss: 0.1419
# Epoch 37/250
# 4/4 [==============================] - 0s 826us/step - loss: 0.1239
# Epoch 38/250
# 4/4 [==============================] - 0s 810us/step - loss: 0.1045
# Epoch 39/250
# 4/4 [==============================] - 0s 847us/step - loss: 0.0928
# Epoch 40/250
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0811
# Epoch 41/250
# 4/4 [==============================] - 0s 842us/step - loss: 0.0783
# Epoch 42/250
# 4/4 [==============================] - 0s 858us/step - loss: 0.0632
# Epoch 43/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0565
# Epoch 44/250
# 4/4 [==============================] - 0s 869us/step - loss: 0.0546
# Epoch 45/250
# 4/4 [==============================] - 0s 811us/step - loss: 0.0472
# Epoch 46/250
# 4/4 [==============================] - 0s 712us/step - loss: 0.0388
# Epoch 47/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0357
# Epoch 48/250
# 4/4 [==============================] - 0s 782us/step - loss: 0.0291
# Epoch 49/250
# 4/4 [==============================] - 0s 858us/step - loss: 0.0244
# Epoch 50/250
# 4/4 [==============================] - 0s 725us/step - loss: 0.0212
# Epoch 51/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0189
# Epoch 52/250
# 4/4 [==============================] - 0s 876us/step - loss: 0.0168
# Epoch 53/250
# 4/4 [==============================] - 0s 722us/step - loss: 0.0133
# Epoch 54/250
# 4/4 [==============================] - 0s 848us/step - loss: 0.0119
# Epoch 55/250
# 4/4 [==============================] - 0s 955us/step - loss: 0.0112
# Epoch 56/250
# 4/4 [==============================] - 0s 789us/step - loss: 0.0092
# Epoch 57/250
# 4/4 [==============================] - 0s 785us/step - loss: 0.0074
# Epoch 58/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0075
# Epoch 59/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0063
# Epoch 60/250
# 4/4 [==============================] - 0s 875us/step - loss: 0.0046
# Epoch 61/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 62/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 63/250
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 64/250
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 65/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 66/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 67/250
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 68/250
# 4/4 [==============================] - 0s 875us/step - loss: 0.0011
# Epoch 69/250
# 4/4 [==============================] - 0s 819us/step - loss: 9.2600e-04
# Epoch 70/250
# 4/4 [==============================] - 0s 942us/step - loss: 7.9979e-04
# Epoch 71/250
# 4/4 [==============================] - 0s 803us/step - loss: 6.8534e-04
# Epoch 72/250
# 4/4 [==============================] - 0s 786us/step - loss: 5.6109e-04
# Epoch 73/250
# 4/4 [==============================] - 0s 689us/step - loss: 4.5885e-04
# Epoch 74/250
# 4/4 [==============================] - 0s 890us/step - loss: 3.7716e-04
# Epoch 75/250
# 4/4 [==============================] - 0s 8ms/step - loss: 3.2072e-04
# Epoch 76/250
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6246e-04
# Epoch 77/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.1966e-04
# Epoch 78/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6889e-04
# Epoch 79/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5550e-04
# Epoch 80/250
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2461e-04
# Epoch 81/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0095e-04
# Epoch 82/250
# 4/4 [==============================] - 0s 1ms/step - loss: 8.3051e-05
# Epoch 83/250
# 4/4 [==============================] - 0s 1ms/step - loss: 5.9462e-05
# Epoch 84/250
# 4/4 [==============================] - 0s 2ms/step - loss: 6.2998e-05
# Epoch 85/250
# 4/4 [==============================] - 0s 2ms/step - loss: 4.2215e-05
# Epoch 86/250
# 4/4 [==============================] - 0s 935us/step - loss: 3.2564e-05
# Epoch 87/250
# 4/4 [==============================] - 0s 992us/step - loss: 2.6478e-05
# Epoch 88/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.1066e-05
# Epoch 89/250
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7764e-05
# Epoch 90/250
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3703e-05
# Epoch 91/250
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0907e-05
# Epoch 92/250
# 4/4 [==============================] - 0s 828us/step - loss: 8.8052e-06
# Epoch 93/250
# 4/4 [==============================] - 0s 2ms/step - loss: 7.2261e-06
# Epoch 94/250
# 4/4 [==============================] - 0s 894us/step - loss: 6.3462e-06
# Epoch 95/250
# 4/4 [==============================] - 0s 912us/step - loss: 4.3574e-06
# Epoch 96/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.3993e-06
# Epoch 97/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.1946e-06
# Epoch 98/250
# 4/4 [==============================] - 0s 777us/step - loss: 2.0560e-06
# Epoch 99/250
# 4/4 [==============================] - 0s 779us/step - loss: 1.5674e-06
# Epoch 100/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2666e-06
# Epoch 101/250
# 4/4 [==============================] - 0s 876us/step - loss: 9.0600e-07
# Epoch 102/250
# 4/4 [==============================] - 0s 1ms/step - loss: 7.3268e-07
# Epoch 103/250
# 4/4 [==============================] - 0s 2ms/step - loss: 5.6758e-07
# Epoch 104/250
# 4/4 [==============================] - 0s 783us/step - loss: 4.4339e-07
# Epoch 105/250
# 4/4 [==============================] - 0s 734us/step - loss: 3.4308e-07
# Epoch 106/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3562e-07
# Epoch 107/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.8588e-07
# Epoch 108/250
# 4/4 [==============================] - 0s 821us/step - loss: 1.3958e-07
# Epoch 109/250
# 4/4 [==============================] - 0s 1ms/step - loss: 9.6884e-08
# Epoch 110/250
# 4/4 [==============================] - 0s 746us/step - loss: 7.3034e-08
# Epoch 111/250
# 4/4 [==============================] - 0s 786us/step - loss: 5.4734e-08
# Epoch 112/250
# 4/4 [==============================] - 0s 723us/step - loss: 5.0121e-08
# Epoch 113/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.5139e-08
# Epoch 114/250
# 4/4 [==============================] - 0s 741us/step - loss: 2.3737e-08
# Epoch 115/250
# 4/4 [==============================] - 0s 724us/step - loss: 1.7447e-08
# Epoch 116/250
# 4/4 [==============================] - 0s 901us/step - loss: 1.0284e-08
# Epoch 117/250
# 4/4 [==============================] - 0s 957us/step - loss: 8.7445e-09
# Epoch 118/250
# 4/4 [==============================] - 0s 756us/step - loss: 7.7144e-09
# Epoch 119/250
# 4/4 [==============================] - 0s 839us/step - loss: 4.2789e-09
# Epoch 120/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.2873e-09
# Epoch 121/250
# 4/4 [==============================] - 0s 878us/step - loss: 2.3773e-09
# Epoch 122/250
# 4/4 [==============================] - 0s 818us/step - loss: 1.7974e-09
# Epoch 123/250
# 4/4 [==============================] - 0s 718us/step - loss: 1.1898e-09
# Epoch 124/250
# 4/4 [==============================] - 0s 1ms/step - loss: 9.0465e-10
# Epoch 125/250
# 4/4 [==============================] - 0s 714us/step - loss: 6.2169e-10
# Epoch 126/250
# 4/4 [==============================] - 0s 778us/step - loss: 4.6266e-10
# Epoch 127/250
# 4/4 [==============================] - 0s 785us/step - loss: 3.2955e-10
# Epoch 128/250
# 4/4 [==============================] - 0s 938us/step - loss: 2.6618e-10
# Epoch 129/250
# 4/4 [==============================] - 0s 780us/step - loss: 4.0407e-10
# Epoch 130/250
# 4/4 [==============================] - 0s 696us/step - loss: 2.6545e-10
# Epoch 131/250
# 4/4 [==============================] - 0s 770us/step - loss: 1.3731e-10
# Epoch 132/250
# 4/4 [==============================] - 0s 996us/step - loss: 8.3744e-11
# Epoch 133/250
# 4/4 [==============================] - 0s 939us/step - loss: 6.3895e-11
# Epoch 134/250
# 4/4 [==============================] - 0s 788us/step - loss: 6.0395e-11
# Epoch 135/250
# 4/4 [==============================] - 0s 752us/step - loss: 5.5181e-11
# Epoch 136/250
# 4/4 [==============================] - 0s 1ms/step - loss: 4.0747e-11
# Epoch 137/250
# 4/4 [==============================] - 0s 720us/step - loss: 4.5819e-11
# Epoch 138/250
# 4/4 [==============================] - 0s 830us/step - loss: 3.4529e-11
# Epoch 139/250
# 4/4 [==============================] - 0s 723us/step - loss: 3.7479e-11
# Epoch 140/250
# 4/4 [==============================] - 0s 900us/step - loss: 3.4537e-11
# Epoch 141/250
# 4/4 [==============================] - 0s 994us/step - loss: 3.1117e-11
# Epoch 142/250
# 4/4 [==============================] - 0s 788us/step - loss: 2.8585e-11
# Epoch 143/250
# 4/4 [==============================] - 0s 716us/step - loss: 2.0175e-11
# Epoch 144/250
# 4/4 [==============================] - 0s 1ms/step - loss: 6.6418e-12
# Epoch 145/250
# 4/4 [==============================] - 0s 853us/step - loss: 4.6518e-12
# Epoch 146/250
# 4/4 [==============================] - 0s 838us/step - loss: 4.2465e-12
# Epoch 147/250
# 4/4 [==============================] - 0s 754us/step - loss: 4.5993e-12
# Epoch 148/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.7367e-12
# Epoch 149/250
# 4/4 [==============================] - 0s 983us/step - loss: 4.4356e-12
# Epoch 150/250
# 4/4 [==============================] - 0s 826us/step - loss: 5.0127e-12
# Epoch 151/250
# 4/4 [==============================] - 0s 704us/step - loss: 2.7065e-12
# Epoch 152/250
# 4/4 [==============================] - 0s 952us/step - loss: 6.9163e-12
# Epoch 153/250
# 4/4 [==============================] - 0s 821us/step - loss: 1.4481e-11
# Epoch 154/250
# 4/4 [==============================] - 0s 885us/step - loss: 1.6884e-11
# Epoch 155/250
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0797e-11
# Epoch 156/250
# 4/4 [==============================] - 0s 6ms/step - loss: 3.7872e-12
# Epoch 157/250
# 4/4 [==============================] - 0s 2ms/step - loss: 4.3158e-12
# Epoch 158/250
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1710e-11
# Epoch 159/250
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7696e-11
# Epoch 160/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.0276e-11
# Epoch 161/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.5995e-11
# Epoch 162/250
# 4/4 [==============================] - 0s 809us/step - loss: 3.2836e-11
# Epoch 163/250
# 4/4 [==============================] - 0s 856us/step - loss: 2.5214e-11
# Epoch 164/250
# 4/4 [==============================] - 0s 774us/step - loss: 1.4309e-11
# Epoch 165/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3313e-11
# Epoch 166/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.2746e-11
# Epoch 167/250
# 4/4 [==============================] - 0s 989us/step - loss: 2.5965e-11
# Epoch 168/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.9681e-11
# Epoch 169/250
# 4/4 [==============================] - 0s 784us/step - loss: 8.5800e-11
# Epoch 170/250
# 4/4 [==============================] - 0s 772us/step - loss: 9.1720e-11
# Epoch 171/250
# 4/4 [==============================] - 0s 1ms/step - loss: 8.7100e-11
# Epoch 172/250
# 4/4 [==============================] - 0s 788us/step - loss: 6.8622e-11
# Epoch 173/250
# 4/4 [==============================] - 0s 779us/step - loss: 8.2703e-11
# Epoch 174/250
# 4/4 [==============================] - 0s 742us/step - loss: 8.5099e-11
# Epoch 175/250
# 4/4 [==============================] - 0s 968us/step - loss: 1.1254e-10
# Epoch 176/250
# 4/4 [==============================] - 0s 781us/step - loss: 8.5963e-11
# Epoch 177/250
# 4/4 [==============================] - 0s 808us/step - loss: 4.9927e-11
# Epoch 178/250
# 4/4 [==============================] - 0s 773us/step - loss: 4.6082e-11
# Epoch 179/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.4888e-11
# Epoch 180/250
# 4/4 [==============================] - 0s 755us/step - loss: 7.2413e-11
# Epoch 181/250
# 4/4 [==============================] - 0s 720us/step - loss: 4.9261e-11
# Epoch 182/250
# 4/4 [==============================] - 0s 712us/step - loss: 1.5264e-11
# Epoch 183/250
# 4/4 [==============================] - 0s 956us/step - loss: 6.6343e-12
# Epoch 184/250
# 4/4 [==============================] - 0s 869us/step - loss: 1.1955e-11
# Epoch 185/250
# 4/4 [==============================] - 0s 896us/step - loss: 2.4491e-11
# Epoch 186/250
# 4/4 [==============================] - 0s 752us/step - loss: 3.5477e-11
# Epoch 187/250
# 4/4 [==============================] - 0s 989us/step - loss: 9.2528e-12
# Epoch 188/250
# 4/4 [==============================] - 0s 806us/step - loss: 5.5837e-12
# Epoch 189/250
# 4/4 [==============================] - 0s 743us/step - loss: 1.4517e-11
# Epoch 190/250
# 4/4 [==============================] - 0s 877us/step - loss: 1.5370e-11
# Epoch 191/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4327e-11
# Epoch 192/250
# 4/4 [==============================] - 0s 728us/step - loss: 1.4162e-11
# Epoch 193/250
# 4/4 [==============================] - 0s 744us/step - loss: 1.0265e-11
# Epoch 194/250
# 4/4 [==============================] - 0s 695us/step - loss: 7.4803e-12
# Epoch 195/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1498e-11
# Epoch 196/250
# 4/4 [==============================] - 0s 857us/step - loss: 2.3253e-11
# Epoch 197/250
# 4/4 [==============================] - 0s 710us/step - loss: 6.4149e-12
# Epoch 198/250
# 4/4 [==============================] - 0s 776us/step - loss: 1.0740e-11
# Epoch 199/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5987e-11
# Epoch 200/250
# 4/4 [==============================] - 0s 925us/step - loss: 1.5440e-11
# Epoch 201/250
# 4/4 [==============================] - 0s 849us/step - loss: 2.6959e-11
# Epoch 202/250
# 4/4 [==============================] - 0s 835us/step - loss: 3.1695e-11
# Epoch 203/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6356e-11
# Epoch 204/250
# 4/4 [==============================] - 0s 821us/step - loss: 7.1633e-12
# Epoch 205/250
# 4/4 [==============================] - 0s 696us/step - loss: 1.3990e-11
# Epoch 206/250
# 4/4 [==============================] - 0s 806us/step - loss: 7.1691e-12
# Epoch 207/250
# 4/4 [==============================] - 0s 940us/step - loss: 5.4254e-12
# Epoch 208/250
# 4/4 [==============================] - 0s 753us/step - loss: 2.7308e-12
# Epoch 209/250
# 4/4 [==============================] - 0s 739us/step - loss: 7.1916e-12
# Epoch 210/250
# 4/4 [==============================] - 0s 858us/step - loss: 1.3928e-11
# Epoch 211/250
# 4/4 [==============================] - 0s 914us/step - loss: 5.6335e-12
# Epoch 212/250
# 4/4 [==============================] - 0s 791us/step - loss: 3.0218e-12
# Epoch 213/250
# 4/4 [==============================] - 0s 733us/step - loss: 3.7628e-12
# Epoch 214/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.8712e-12
# Epoch 215/250
# 4/4 [==============================] - 0s 956us/step - loss: 6.2762e-12
# Epoch 216/250
# 4/4 [==============================] - 0s 710us/step - loss: 6.1312e-12
# Epoch 217/250
# 4/4 [==============================] - 0s 779us/step - loss: 9.0844e-12
# Epoch 218/250
# 4/4 [==============================] - 0s 1ms/step - loss: 3.8911e-12
# Epoch 219/250
# 4/4 [==============================] - 0s 1ms/step - loss: 2.9976e-12
# Epoch 220/250
# 4/4 [==============================] - 0s 729us/step - loss: 5.5751e-12
# Epoch 221/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0061e-11
# Epoch 222/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1934e-11
# Epoch 223/250
# 4/4 [==============================] - 0s 919us/step - loss: 4.8296e-12
# Epoch 224/250
# 4/4 [==============================] - 0s 791us/step - loss: 2.7064e-12
# Epoch 225/250
# 4/4 [==============================] - 0s 964us/step - loss: 7.3555e-12
# Epoch 226/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2661e-11
# Epoch 227/250
# 4/4 [==============================] - 0s 822us/step - loss: 5.4523e-12
# Epoch 228/250
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7086e-12
# Epoch 229/250
# 4/4 [==============================] - 0s 3ms/step - loss: 7.3652e-12
# Epoch 230/250
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7135e-12
# Epoch 231/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.8796e-11
# Epoch 232/250
# 4/4 [==============================] - 0s 715us/step - loss: 1.2553e-11
# Epoch 233/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5187e-11
# Epoch 234/250
# 4/4 [==============================] - 0s 1ms/step - loss: 6.8639e-12
# Epoch 235/250
# 4/4 [==============================] - 0s 679us/step - loss: 1.2005e-11
# Epoch 236/250
# 4/4 [==============================] - 0s 835us/step - loss: 4.1861e-12
# Epoch 237/250
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9862e-12
# Epoch 238/250
# 4/4 [==============================] - 0s 663us/step - loss: 2.7197e-12
# Epoch 239/250
# 4/4 [==============================] - 0s 800us/step - loss: 7.1552e-12
# Epoch 240/250
# 4/4 [==============================] - 0s 971us/step - loss: 2.7153e-12
# Epoch 241/250
# 4/4 [==============================] - 0s 953us/step - loss: 7.1015e-12
# Epoch 242/250
# 4/4 [==============================] - 0s 834us/step - loss: 1.4917e-11
# Epoch 243/250
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5966e-11
# Epoch 244/250
# 4/4 [==============================] - 0s 839us/step - loss: 9.8233e-12
# Epoch 245/250
# 4/4 [==============================] - 0s 1ms/step - loss: 4.4098e-12
# Epoch 246/250
# 4/4 [==============================] - 0s 756us/step - loss: 4.5026e-12
# Epoch 247/250
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0816e-11
# Epoch 248/250
# 4/4 [==============================] - 0s 670us/step - loss: 6.4739e-12
# Epoch 249/250
# 4/4 [==============================] - 0s 663us/step - loss: 2.7063e-12
# Epoch 250/250
# 4/4 [==============================] - 0s 664us/step - loss: 5.9221e-12

# %% [markdown]
# ## Evaluating the Model
#
# Now we evaluate the created model where we can observe that the loss (Training_loss) decreases as more iterations (epoch) are performed, which is logical if the training set data makes sense and is a large enough group.

# %%
print("Evaluating the model")
print(epochs_hist.history.keys())
	
#graph
plt.plot(epochs_hist.history['loss'])
plt.title('Evolution of the error associated with the model')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend('Training Loss')
plt.show()
# Out:
# Evaluating the model
# dict_keys(['loss'])

# %% [markdown]
# We can see from the graph that training the model with 250 steps does not help much and that the error does not decrease after the 50th iteration.
#
# Therefore, the optimal number of steps to train this algorithm would be approximately 50 steps.

# %% [markdown]
# ## Making the Prediction
#
# Now that we have trained our model, we can use it to make a prediction.
#
# In this case, we assign the value 100 to the model input variable, and the model will return the prediction in miles:

# %%
kilometers = 100
predictedMiles = model.predict([kilometers])
print("The conversion from Kilometres to Miles is as follows: " + str(predictedMiles))
# Out:
# 1/1 [==============================] - 0s 42ms/step
# The conversion from Kilometres to Miles is as follows: [[62.13712]]

# %% [markdown]
# ## Checking the Result
#
# The conversion from kilometers to miles using the mathematical formula is as follows: 62.13999999999999 Prediction error: 0.00618362

# %%
milesByFormula = kilometers * k_m
print("The conversion from kilometers to miles using the mathematical formula is as follows:" + str(milesByFormula))
diference = milesByFormula - predictedMiles
print("Prediction error:" + str( ))
# Out:
# The conversion from kilometers to miles using the mathematical formula is as follows:62.1371192
# Prediction error:[[0.]]

# %% [markdown]
# ## Final Thoughts
#
# Through this example, we have seen how to use the TensorFlow library to create a model that has learned to convert kilometers to miles automatically and with a low error.
#
# The mathematics that TensorFlow uses to perform this process is quite simple. Basically, this example uses linear regression to create the model since the input variables: kilometers and the output variables: miles are correlated.
#
# In machine learning, the most time-consuming part of the process is usually preparing the data.
#
# Over time, we gain experience and some intuition that help us choose the most suitable algorithm and its settings, but in general, it is a task to analyze-test and improve.
