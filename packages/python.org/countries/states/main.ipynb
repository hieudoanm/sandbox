# %%
import pandas as pd

# %%
states_data_frame = pd.read_csv("./states.csv")
states_data_frame = states_data_frame.sort_values(by=["country", "level"])
states_data_frame.to_csv("./states.csv", index=False)
states_data_frame
# Out:
#        country macroregion             region               level  \
# 0    Australia         NaN                NaN  External Territory
# 1    Australia         NaN                NaN  External Territory
# 2    Australia         NaN                NaN  External Territory
# 3    Australia         NaN                NaN  External Territory
# 4    Australia         NaN                NaN  External Territory
# ..         ...         ...                ...                 ...
# 236    Vietnam     Central  Central Highlands            province
# 237    Vietnam     Central  Central Highlands            province
# 238    Vietnam     Central  Central Highlands            province
# 239    Vietnam     Central  Central Highlands            province
# 240    Vietnam     Central  Central Highlands            province
#
#                                   name native_name postal code  \
# 0       Australian Antarctic Territory         NaN    TAS   AQ
# ...
